# %% [markdown]
# ## Log
# Created to keep notes on process and thoughts

# %% [markdown]
# ### 2024/08/03 5:56pm - Liam
# - Created this file post model creation
# - Comedically inaccuate model, but it's a start
# - Putting log below

# %% [markdown]
# Current working directory: C:\Mocha\NEU\ds5110\MBTI4Readers\src
# Attempting to load data from: C:\Mocha\NEU\ds5110\MBTI4Readers\data\copy\bookMeta.json
# Successfully loaded data. Shape before preprocessing: (72504, 47)
# Shape after preprocessing: (72504, 47)
# Successfully loaded data. Shape: (72504, 47)
# Columns: ['title', 'subtitle', 'author', 'foreword', 'editor', 'illustrator', 'creators', 'synopsis', 'publisher', 'characterEthnicity', 'characterGenderIdentity', 'characterRaceCulture', 'characterReligion', 'characterSexualOrientation', 'awards', 'contentWarning', 'timePeriod', 'narrativeForm', 'genre', 'historicalEvents', 'internationalAwards', 'language', 'languageRegister', 'literaryDevices', 'modesOfWriting', 'pointOfView', 'subject', 'textFeatures', 'textStructure', 'topic', 'voice', 'tags', 'isFiction', 'isNonFiction', 'isBlended', 'guidedReadingLevel', 'lexileLevel', 'hasMultiplePov', 'hasUnreliableNarrative', 'isbn10', 'isbn13', 'series', 'seriesBookNumber', 'seriesType', 'pubDate', 'images', 'binding']
# Data types: title                         object
# subtitle                      object
# author                        object
# foreword                      object
# editor                        object
# illustrator                   object
# creators                      object
# synopsis                      object
# publisher                     object
# characterEthnicity            object
# characterGenderIdentity       object
# characterRaceCulture          object
# characterReligion             object
# characterSexualOrientation    object
# awards                        object
# contentWarning                object
# timePeriod                    object
# narrativeForm                 object
# genre                         object
# historicalEvents              object
# internationalAwards           object
# language                      object
# languageRegister              object
# literaryDevices               object
# modesOfWriting                object
# pointOfView                   object
# subject                       object
# textFeatures                  object
# textStructure                 object
# topic                         object
# voice                         object
# tags                          object
# isFiction                      int64
# isNonFiction                   int64
# isBlended                      int64
# guidedReadingLevel            object
# lexileLevel                   object
# hasMultiplePov                 int64
# hasUnreliableNarrative         int64
# isbn10                        object
# isbn13                        object
# series                        object
# seriesBookNumber               int64
# seriesType                    object
# pubDate                       object
# images                        object
# binding                       object
# dtype: object
# Column lexileLevel contains 172 NaN values. Filling with mean.
# Features engineered. Shape: (72504, 50)
# Engineered features: ['PCA_0', 'PCA_1', 'PCA_2', 'PCA_3', 'PCA_4', 'PCA_5', 'PCA_6', 'PCA_7', 'PCA_8', 'PCA_9', 'PCA_10', 'PCA_11', 'PCA_12', 'PCA_13', 'PCA_14', 'PCA_15', 'PCA_16', 'PCA_17', 'PCA_18', 'PCA_19', 'PCA_20', 'PCA_21', 'PCA_22', 'PCA_23', 'PCA_24', 'PCA_25', 'PCA_26', 'PCA_27', 'PCA_28', 'PCA_29', 'PCA_30', 'PCA_31', 'PCA_32', 'PCA_33', 'PCA_34', 'PCA_35', 'PCA_36', 'PCA_37', 'PCA_38', 'PCA_39', 'PCA_40', 'PCA_41', 'PCA_42', 'PCA_43', 'PCA_44', 'PCA_45', 'PCA_46', 'PCA_47', 'PCA_48', 'PCA_49']
# Clustering Cross-Validation Results:
# Mean Silhouette Score: 0.7036 (+/- 0.2253)
# Recommendation Cross-Validation Results:
# Mean Precision: 0.8000 (+/- 0.4000)
# Clustering completed. Number of clusters: 5
# Cluster profiles created. Number of profiles: 5
# Cluster 0:
#   Size: 71868
#   Top genres: {'': 64985, 'Fiction: Realistic': 2589, 'Fiction: Fantasy': 548}
#   Most common narrative form: []
#
# Cluster 2:
#   Size: 618
#   Top genres: {'Fiction: Realistic': 266, '': 95, 'Biography, Nonfiction: Narrative (Bios)': 83}
#   Most common narrative form: ['General Formats', 'Novels']
#
# Cluster 4:
#   Size: 11
#   Top genres: {'': 4, 'Biography, Nonfiction: Narrative (Bios)': 2, 'Nonfiction: Traditional': 2}
#   Most common narrative form: []
#
# Cluster 3:
#   Size: 3
#   Top genres: {'': 2, 'Fiction: Traditional Literature': 1}
#   Most common narrative form: []
#
# Cluster 1:
#   Size: 4
#   Top genres: {'': 4}
#   Most common narrative form: []
#
# Cluster 0 top genres: , Fiction: Realistic, Fiction: Fantasy
# Cluster 1 top genres:
# Cluster 2 top genres: Fiction: Realistic, , Biography, Nonfiction: Narrative (Bios)
# Cluster 3 top genres: , Fiction: Traditional Literature
# Cluster 4 top genres: , Biography, Nonfiction: Narrative (Bios), Nonfiction: Traditional
# Recommended books:
# 0                                    Michigan vs. the Boys
# 72503                               Euphoria (Deckle edge)
# 72502    100 Ways to Make the World a Better Place: An ...
# 72501                     Honest June: The Show Must Go On
# 72500                                 Operation Sisterhood
# Name: title, dtype: object

# %% [markdown]
# #### Analysis
#
# What is it saying?
# - Clustering Cross-Validation:
#     - Mean Silhouette Score: 0.7036 (+/- 0.2253)
#         - good silhouette score,
#                 - indicating that the clusters are generally well-defined.
#         - the high standard deviation suggests some inconsistency across folds
# - Recommendation Cross-Validation:
#     - Mean Precision: 0.8000 (+/- 0.4000)
#         - The precision is good, but the high standard deviation indicates inconsistent performance across folds again lol
# - Clustering Results:
#     - The clustering has produced 5 clusters, but they are highly imbalanced:
#         - Cluster 0: 71,868 books (98.9% of the dataset)
#         - Cluster 2: 618 books
#         - Clusters 1, 3, and 4: Very small (4-11 books each)
# - Many clusters have no common narrative form, which suggests that the clustering may not be capturing meaningful patterns in the data (or that the narrative form feature is not useful for clustering).
#
# Sample Data used:
#
#     try:
#         user_preferences = {
#             'genre': 'fantasy',
#             'isFiction': 1,
#         }
#         user_profile = create_user_profile(user_preferences, book_features)
#         recommendations = recommend_books(user_profile, book_features)
#
#         print("Recommended books:")
#         print(df.loc[recommendations, 'title'])
#
#
# - The model is not accurate.
#     - "Michigan vs. the Boys" - likely sports fiction
#     - "Euphoria" - appears to be literary fiction
#     - "100 Ways to Make the World a Better Place" - likely non-fiction
#     - "Honest June: The Show Must Go On" - possibly children's or young adult fiction
#     - "Operation Sisterhood" - possibly children's or young adult fiction
#
# - Possible reasons for inaccuracy:
#     - The 'genre' feature might not be properly encoded or weighted in the book features.
#         - might not be effectively using the genre information when making recommendations.
#
#     - might be issues with how genres are assigned or represented in the dataset.
#     - method used to calculate similarity between user preferences and book features might not be appropriate.
